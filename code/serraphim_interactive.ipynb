# %% [markdown]
# ### Install pyenv on WSL
#
# ```
# # Clone pyenv
# curl https://pyenv.run | bash
# # Add to your shell startup (e.g. ~/.bashrc or ~/.zshrc):
# export PATH="$HOME/.pyenv/bin:$PATH"
# eval "$(pyenv init --path)"
# eval "$(pyenv init -)"
# eval "$(pyenv virtualenv-init -)"
# # Then reload:
# exec $SHELL
# ```
#
# ### Build Python 3.10.12
#
# ```
# pyenv install 3.10.12
# # Verify:
# pyenv versions
# ```
#
# ### Create & activate a pyenv-venv
#
# ```
# pyenv virtualenv 3.10.12 yakuza_venv
# pyenv activate yakuza_venv
# ```
#
# ### Install Jupyter & ipykernel to work with Jypyter Notebooks
#
# ```
# pip install jupyter ipykernel
# ```
#
# ### Install necessary libraries
#
# ```
# pip install numpy pandas torch Bio transformers fair-esm xgboost scikit-learn
# ```

# %% [markdown]
# ### Download Serratia bacterial genomes from NCBI
#
# ```
# pip install ncbi-genome-download
# ncbi-genome-download \
#     --section genbank \
#     --formats fasta \
#     --assembly-levels complete \
#     --species-taxid 615,82996 \
#     --output-folder ./data/ncbi_bacteria \
#     bacteria
# ```

# %% [markdown]
# ### pharokka installation
# #### Using pip:
# ```
# pip install pharokka PHANOTATE
# git clone https://github.com/gbouras13/pharokka.git
# ```
#
# #### Alternatively with conda:
# ```
# sudo apt install -y wget git build-essential hmmer barrnap trnascan-se
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# bash Miniconda3-latest-Linux-x86_64.sh
# ```
# #### Restart terminal to finalize conda installation
# ```
# conda env create -f pharokka/environment.yml
# conda activate pharokka_env
# ```
#
# ### Install pharokka databases:
# ```
# ./pharokka/bin/install_databases.py
# ```
#
# #### MMseqs2:
# ```
# wget https://github.com/soedinglab/MMseqs2/releases/download/13-45111/mmseqs-linux-avx2.tar.gz
# tar xvfz mmseqs-linux-avx2.tar.gz
# ```
#
# #### MinCED:
# ```
# sudo apt install openjdk-11-jre
# sudo apt install openjdk-11-jdk-headless
# git clone https://github.com/ctSkennerton/minced.git
# cd minced
# make
# sudo cp minced.jar /usr/local/bin/
# sudo cp minced /usr/local/bin/
# cd ..
# ```
#
# #### ARAGORN:
# ```
# mkdir aragorn; cd aragorn
# wget https://anaconda.org/bioconda/aragorn/1.2.41/download/linux-64/aragorn-1.2.41-h031d066_3.tar.bz2
# tar -xvjf aragorn-1.2.41-h031d066_3.tar.bz2
# sudo cp bin/aragorn /usr/local/bin/
# cd ..
# ```
#
# #### Mash:
# ```
# wget https://github.com/marbl/Mash/releases/download/v2.3/mash-Linux64-v2.3.tar
# tar -xvf mash-Linux64-v2.3.tar
# sudo cp mash-Linux64-v2.3/mash /usr/local/bin/
# ```
#
# #### Dnaapler:
# ```
# pip3 install dnaapler
# ```

# %% [markdown]
# ### Install RBPdetect_v4_ESMfinetuned
#
# ```
# sudo apt install unzip
# wget 'https://zenodo.org/records/14810759/files/RBPdetect_v4_ESMfine.zip?download=1' -O 'RBPdetect_v4_ESMfine.zip'
# unzip ./RBPdetect_v4_ESMfine.zip -d .
# rm -f RBPdetect_v4_ESMfine.zip
# ```

# %% [markdown]
# ### Bakta
# #### Using conda (recommended):
# ```
# conda install -c conda-forge -c bioconda bakta
# ```
#
# #### Using pip (must install 3rd party dependencies manually):
# ```
# pip install bakta
# ```
#
# ### AMRFinderPlus:
# ```
# mkdir AMRFinderPlus; cd AMRFinderPlus
# wget https://github.com/ncbi/amr/releases/download/amrfinder_v4.0.3/amrfinder_binaries_v4.0.3.tar.gz
# tar -xvzf amrfinder_binaries_v4.0.3.tar.gz
# cd ..
# sudo cp ./AMRFinderPlus/* /usr/local/bin/
# ```
#
# ### PILER-CR:
# ```
# wget http://www.drive5.com/pilercr/pilercr1.06.tar.gz
# tar -xvzf pilercr1.06.tar.gz
# cd pilercr1.06
# make
# sudo cp ./pilercr /usr/local/bin/
# cd ..
# ```
#
# ### Diamond:
# ```
# wget https://github.com/bbuchfink/diamond/releases/download/v2.1.10/diamond-linux64.tar.gz
# tar -xvzf diamond-linux64.tar.gz
# sudo mv diamond /usr/local/bin/
# ```
#
# ### Blast+ (update from 2.12.0 to 2.14.0):
# ```
# sudo apt remove -y ncbi-blast+
# wget https://ftp.ncbi.nlm.nih.gov/blast/executables/blast+/2.14.0/ncbi-blast-2.14.0+-x64-linux.tar.gz
# tar -xvzf ncbi-blast-2.14.0+-x64-linux.tar.gz
# sudo mv ncbi-blast-2.14.0+/bin/* /usr/local/bin/
# ```
#
# ## Install full database (~30GB):
# ```
# mkdir bakta_db
# bakta_db download --output ./bakta_db --type full
# ```
#
# ### Run against a single genome .fasta:
# ```
# mkdir ./data/bakta_test
# bakta --db ./bakta_db/db --output ./data/bakta_test --force ./data/bacteria_genomes/33KP-HG.fasta
# bakta --db ./bakta_db/db \
#       --output ./data/bakta_test \
#       --force \
#       --skip-trna \
#       --skip-tmrna \
#       --skip-rrna \
#       --skip-ncrna \
#       --skip-ncrna-region \
#       --skip-crispr \
#       --skip-pseudo \
#       --skip-sorf \
#       --skip-gap \
#       --skip-plot \
#       ./data/bacteria_genomes/33KP-HG.fasta
# ```
#
# ### In general:
# #### For training:
# ```
# bakta --db ./bakta_db/db \
#       --output <bakta_output_path> \
#       --force \
#       --skip-trna \
#       --skip-tmrna \
#       --skip-rrna \
#       --skip-ncrna \
#       --skip-ncrna-region \
#       --skip-crispr \
#       --skip-pseudo \
#       --skip-sorf \
#       --skip-gap \
#       --skip-plot \
#       <serratia_genome>.fasta
# ```
# #### For inference:
# ```
# bakta --db <db_path> \
#       --output <bakta_output_path> \
#       --force \
#       <serratia_genome>.fasta
# ```

# %% [markdown]
# ### Ray Tune
#
# ```
# pip install ray[tune]
# ```

# %%
# 1 - INITIAL SETUP
# --------------------------------------------------
import numpy as np
import pickle
from tqdm import tqdm
from pathlib import Path
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from functools import partial
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, accuracy_score

import serraphim_processing as sp
import serraphim_features as sf

# Project path
main_path = '/home/snt/SerraPHIM'

# General paths
code_path = main_path + '/code'
data_path = main_path + '/data'
results_path = main_path + '/results'

# Bacterial genome data paths
bact_genomes_path = data_path + '/bacteria_genomes'
ncbi_bact_path = data_path + '/ncbi_bacteria/genbank/bacteria'

# Phage genome data and metadata paths
phage_genomes_path = data_path + '/phage_genomes'
phagescope_multiFASTA_path = data_path + '/PhageScope_data/PhageScope_virulent_complete-HQ_sequences.fasta'

phagescope_metadata_path = data_path + '/PhageScope_metadata'
metadata_file = 'serratia_complete-HQ_virulent_phage_metadata.tsv'

data_suffix = '_training'

# Software and database paths
phl_path = '/home/snt/PhageHostLearn-main'
pharokka_executable_path = phl_path + '/pharokka/bin/pharokka.py'
pharokka_db_path = phl_path + '/pharokka/databases'

RBP_detect_model_path = main_path + '/RBPdetect_v4_ESMfine'

bakta_db_path = phl_path + '/bakta_db/db'
bakta_results_path = data_path + '/bakta_results'

# Paths for testing purposes:
phage_genomes_sample_path = phage_genomes_path + '/sample'
bact_genomes_sample_path = bact_genomes_path + '/sample'

# %%
# 2 - DATA PROCESSING
# --------------------------------------------------

# Check if the bacterial genomes' directory exists and is empty
if not Path(bact_genomes_path).exists() or not any(Path(bact_genomes_path).iterdir()):
    print("Bacterial genomes' directory is empty. Processing NCBI FASTA files...")
    sp.process_ncbi_fasta(
        input_root=ncbi_bact_path,
        output_root=bact_genomes_path,
        combine_plasmids="True"
    )
    # combine_plasmids="True" -> 284 FASTA files saved (plasmid-only FNA files skipped)
    # combine_plasmids="False" -> 578 FASTA files saved
else:
    print("Bacterial genomes' directory is not empty. Moving on...")
    pass
# Out:
# Bacterial genomes' directory is not empty. Moving on...

# %%
# Create or load phage metadata
phage_metadata = sp.load_or_create_curated_phage_metadata(
    phagescope_metadata_path,
    metadata_file
)

# Split the multi-FASTA file manually created using PhageScope
if not Path(phage_genomes_path).exists() or not any(Path(phage_genomes_path).iterdir()):
    print("Phage genomes' directory is empty. Processing PhageScope multi-FASTA file...")
    sp.split_fasta_by_phage_id(
        phagescope_multiFASTA_path,
        phage_genomes_path
    )
else:
    print("Phage genomes' directory is not empty. Moving on...")
    pass
# Out:
# Metadata file already exists: serratia_complete-HQ_virulent_phage_metadata.tsv
# Phage genomes' directory is not empty. Moving on...

# %%
# Derive interaction matrix
interaction_filepath = data_path + f'/interactions/phage_host_interactions{data_suffix}.csv'

phage_host_interaction_matrix = sp.derive_phage_host_interaction_matrix(
    bact_genomes_path,
    phage_metadata,
    interaction_filepath
)
# Out:
# Interaction matrix already exists at: /home/snt/SerraPHIM/data/interactions/phage_host_interactions_training.csv

# %%
# Run pharokka
sp.pharokka_processing(
    data_path, 
    phage_genomes_path, # phage_genomes_path or phage_genomes_sample_path
    pharokka_executable_path, 
    pharokka_db_path, 
    data_suffix,
    threads=16  # 128 cores in yakuza server
)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# 2025-07-25 15:51:20.958 | INFO     | input_commands:instantiate_dirs:190 - Removing output directory /home/snt/SerraPHIM/data/pharokka_results/uvig_32658 as -f or --force was specified.
# 2025-07-25 15:51:20.963 | INFO     | __main__:main:95 - Starting Pharokka v1.7.5
# 2025-07-25 15:51:20.963 | INFO     | __main__:main:96 - Command executed: Namespace(infile='/home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta', outdir='/home/snt/SerraPHIM/data/pharokka_results/uvig_32658', database='/home/snt/PhageHostLearn-main/pharokka/databases', threads='16', force=True, prefix='Default', locustag='Default', gene_predictor='default', meta=False, split=False, coding_table='11', evalue='1E-05', fast=False, mmseqs2_only=False, meta_hmm=False, dnaapler=False, custom_hmm='', genbank=False, terminase=False, terminase_strand='nothing', terminase_start='nothing', skip_extra_annotations=False, skip_mash=False, minced_args='', mash_distance=0.2, trna_scan_model='general', citation=False)
# 2025-07-25 15:51:20.963 | INFO     | __main__:main:97 - Repository homepage is https://github.com/gbouras13/pharokka
# 2025-07-25 15:51:20.963 | INFO     | __main__:main:98 - Written by George Bouras: george.bouras@adelaide.edu.au
# 2025-07-25 15:51:20.964 | INFO     | __main__:main:100 - Checking database installation in /home/snt/PhageHostLearn-main/pharokka/databases.
# 2025-07-25 15:51:20.965 | INFO     | __main__:main:103 - All databases have been successfully checked.
# 2025-07-25 15:51:20.966 | INFO     | __main__:main:119 - Checking dependencies.
# 2025-07-25 15:51:21.121 | INFO     | input_commands:check_dependencies:390 - Phanotate version found is v1.6.7
# 2025-07-25 15:51:21.121 | INFO     | input_commands:check_dependencies:399 - Phanotate version is ok.
# 2025-07-25 15:51:21.141 | INFO     | input_commands:check_dependencies:420 - MMseqs2 version found is 45111b641859ed0ddd875b94d6fd1aef1a675b7e
# 2025-07-25 15:51:21.141 | INFO     | input_commands:check_dependencies:435 - MMseqs2 version is ok.
# 2025-07-25 15:51:21.237 | INFO     | input_commands:check_dependencies:459 - tRNAscan-SE version found is v2.0.12
# 2025-07-25 15:51:21.237 | INFO     | input_commands:check_dependencies:470 - tRNAscan-SE version is ok.
# 2025-07-25 15:51:21.386 | INFO     | input_commands:check_dependencies:494 - MinCED version found is v0.4.2
# 2025-07-25 15:51:21.387 | INFO     | input_commands:check_dependencies:505 - MinCED version is ok.
# 2025-07-25 15:51:21.389 | INFO     | input_commands:check_dependencies:531 - ARAGORN version found is v1.2.41
# 2025-07-25 15:51:21.390 | INFO     | input_commands:check_dependencies:542 - ARAGORN version is ok.
# 2025-07-25 15:51:21.395 | INFO     | input_commands:check_dependencies:559 - mash version found is v2.3
# 2025-07-25 15:51:21.395 | INFO     | input_commands:check_dependencies:566 - mash version is ok.
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:585 - Dnaapler version found is v1.2.0
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:592 - Dnaapler version is ok.
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:604 - Pyrodigal version is v3.6.3
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:605 - Pyrodigal version is ok.
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:617 - Pyrodigal_gv version is v0.3.2
# 2025-07-25 15:51:21.820 | INFO     | input_commands:check_dependencies:618 - Pyrodigal_gv version is ok.
# 2025-07-25 15:51:21.838 | INFO     | input_commands:validate_fasta:237 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta.
# 2025-07-25 15:51:21.838 | INFO     | input_commands:validate_fasta:239 - Input /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta is in FASTA format.
# 2025-07-25 15:51:21.838 | INFO     | input_commands:validate_fasta:244 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta for duplicate FASTA headers.
# 2025-07-25 15:51:21.838 | INFO     | input_commands:validate_fasta:246 - All headers in /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta are unique.
# 2025-07-25 15:51:21.838 | INFO     | input_commands:validate_gene_predictor:275 - Phanotate will be used for gene prediction.
# 2025-07-25 15:51:21.838 | INFO     | __main__:main:280 - Running Phanotate.
# 2025-07-25 15:51:21.840 | INFO     | external_tools:run:50 - Started running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta ...
# 2025-07-25 15:51:23.498 | INFO     | external_tools:run:52 - Done running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta
# 2025-07-25 15:51:23.498 | INFO     | external_tools:run:50 - Started running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta ...
# 2025-07-25 15:51:25.093 | INFO     | external_tools:run:52 - Done running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta
# 2025-07-25 15:51:25.101 | INFO     | __main__:main:309 - Starting tRNA-scanSE.
# 2025-07-25 15:51:25.101 | INFO     | external_tools:run:50 - Started running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta ...
# 2025-07-25 15:51:25.282 | INFO     | external_tools:run:52 - Done running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta
# 2025-07-25 15:51:25.283 | INFO     | processes:run_minced:827 - Running MinCED.
# 2025-07-25 15:51:25.283 | INFO     | external_tools:run:50 - Started running minced /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_minced.gff ...
# 2025-07-25 15:51:25.365 | INFO     | external_tools:run:52 - Done running minced /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_minced.gff
# 2025-07-25 15:51:25.365 | INFO     | processes:run_aragorn:859 - Running Aragorn.
# 2025-07-25 15:51:25.366 | INFO     | external_tools:run:50 - Started running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta ...
# 2025-07-25 15:51:25.370 | INFO     | external_tools:run:52 - Done running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta
# 2025-07-25 15:51:25.371 | INFO     | __main__:main:317 - Starting MMseqs2.
# 2025-07-25 15:51:25.371 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on PHROG Database.
# 2025-07-25 15:51:25.371 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs ...
# 2025-07-25 15:51:25.384 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs
# 2025-07-25 15:51:25.385 | INFO     | external_tools:run:50 - Started running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/tmp_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:53:01.417 | INFO     | external_tools:run:52 - Done running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/tmp_dir/ -s 8.5 --threads 16
# 2025-07-25 15:53:01.418 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:53:01.459 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/mmseqs_results.tsv --full-header --threads 16
# 2025-07-25 15:53:01.459 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on CARD Database.
# 2025-07-25 15:53:01.460 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs ...
# 2025-07-25 15:53:01.469 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs
# 2025-07-25 15:53:01.470 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:53:15.481 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_dir/ -s 8.5 --threads 16
# 2025-07-25 15:53:15.482 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:53:15.500 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/CARD_results.tsv --full-header --threads 16
# 2025-07-25 15:53:15.501 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on VFDB Database.
# 2025-07-25 15:53:15.502 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs ...
# 2025-07-25 15:53:15.512 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs
# 2025-07-25 15:53:15.513 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:53:39.798 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_dir/ -s 8.5 --threads 16
# 2025-07-25 15:53:39.799 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/vfdb_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:53:39.816 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/vfdb_results.tsv --full-header --threads 16
# 2025-07-25 15:53:39.817 | INFO     | __main__:main:348 - Running PyHMMER on PHROGs.
# 2025-07-25 15:53:47.358 | INFO     | __main__:main:364 - Post Processing Output.
# 2025-07-25 15:53:47.364 | INFO     | post_processing:create_mmseqs_tophits:2146 - Processing MMseqs2 outputs.
# 2025-07-25 15:53:47.364 | INFO     | post_processing:create_mmseqs_tophits:2147 - Processing PHROGs output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2169: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "mmseqs_eVal"))
# 2025-07-25 15:53:47.440 | INFO     | post_processing:process_vfdb_results:2351 - Processing VFDB output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2375: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "vfdb_eVal"))
# 2025-07-25 15:53:47.446 | INFO     | post_processing:process_vfdb_results:2437 - 0 VFDB virulence factors identified.
# 2025-07-25 15:53:47.446 | INFO     | post_processing:process_card_results:2455 - Processing CARD output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2475: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "CARD_eVal"))
# 2025-07-25 15:53:47.451 | INFO     | post_processing:process_card_results:2578 - 0 CARD AMR genes identified.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:1110: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   total_gff = total_gff.groupby(
# 2025-07-25 15:53:47.479 | INFO     | __main__:main:435 - Converting gff to genbank.
# 2025-07-25 15:53:47.486 | INFO     | post_processing:extract_terl:1982 - Terminase large subunit found.
# 2025-07-25 15:53:47.487 | INFO     | __main__:main:453 - Finding the closest match for each contig in INPHARED using mash.
# 2025-07-25 15:53:47.488 | INFO     | external_tools:run:50 - Started running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/input_mash_sketch.msh -i ...
# 2025-07-25 15:53:47.492 | INFO     | external_tools:run:52 - Done running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/uvig_32658.fasta -o /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/input_mash_sketch.msh -i
# 2025-07-25 15:53:47.492 | INFO     | external_tools:run_to_stdout:59 - Started running mash dist /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i ...
# 2025-07-25 15:53:48.336 | INFO     | external_tools:run_to_stdout:61 - Done running mash dist /home/snt/SerraPHIM/data/pharokka_results/uvig_32658/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:473 - Pharokka has finished.
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:474 - Elapsed time: 147.47 seconds
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:476 - If you use Pharokka in your research, please cite:
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:477 - George Bouras, Roshan Nepal, Ghais Houtak, Alkis James Psaltis, Peter-John Wormald, Sarah Vreugde.
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:480 - Pharokka: a fast scalable bacteriophage annotation tool.
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:481 - Bioinformatics, Volume 39, Issue 1, January 2023, btac776.
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:482 - https://doi.org/10.1093/bioinformatics/btac776.
# 2025-07-25 15:53:48.429 | INFO     | __main__:main:483 - You should also cite the full list of tools Pharokka uses, which can be found at https://github.com/gbouras13/pharokka#citation.
#  20%|██        | 1/5 [02:28<09:54, 148.59s/it]
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# 2025-07-25 15:53:49.243 | INFO     | input_commands:instantiate_dirs:190 - Removing output directory /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631 as -f or --force was specified.
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:95 - Starting Pharokka v1.7.5
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:96 - Command executed: Namespace(infile='/home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta', outdir='/home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631', database='/home/snt/PhageHostLearn-main/pharokka/databases', threads='16', force=True, prefix='Default', locustag='Default', gene_predictor='default', meta=False, split=False, coding_table='11', evalue='1E-05', fast=False, mmseqs2_only=False, meta_hmm=False, dnaapler=False, custom_hmm='', genbank=False, terminase=False, terminase_strand='nothing', terminase_start='nothing', skip_extra_annotations=False, skip_mash=False, minced_args='', mash_distance=0.2, trna_scan_model='general', citation=False)
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:97 - Repository homepage is https://github.com/gbouras13/pharokka
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:98 - Written by George Bouras: george.bouras@adelaide.edu.au
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:100 - Checking database installation in /home/snt/PhageHostLearn-main/pharokka/databases.
# 2025-07-25 15:53:49.253 | INFO     | __main__:main:103 - All databases have been successfully checked.
# 2025-07-25 15:53:49.254 | INFO     | __main__:main:119 - Checking dependencies.
# 2025-07-25 15:53:49.349 | INFO     | input_commands:check_dependencies:390 - Phanotate version found is v1.6.7
# 2025-07-25 15:53:49.349 | INFO     | input_commands:check_dependencies:399 - Phanotate version is ok.
# 2025-07-25 15:53:49.351 | INFO     | input_commands:check_dependencies:420 - MMseqs2 version found is 45111b641859ed0ddd875b94d6fd1aef1a675b7e
# 2025-07-25 15:53:49.351 | INFO     | input_commands:check_dependencies:435 - MMseqs2 version is ok.
# 2025-07-25 15:53:49.393 | INFO     | input_commands:check_dependencies:459 - tRNAscan-SE version found is v2.0.12
# 2025-07-25 15:53:49.393 | INFO     | input_commands:check_dependencies:470 - tRNAscan-SE version is ok.
# 2025-07-25 15:53:49.433 | INFO     | input_commands:check_dependencies:494 - MinCED version found is v0.4.2
# 2025-07-25 15:53:49.434 | INFO     | input_commands:check_dependencies:505 - MinCED version is ok.
# 2025-07-25 15:53:49.435 | INFO     | input_commands:check_dependencies:531 - ARAGORN version found is v1.2.41
# 2025-07-25 15:53:49.435 | INFO     | input_commands:check_dependencies:542 - ARAGORN version is ok.
# 2025-07-25 15:53:49.437 | INFO     | input_commands:check_dependencies:559 - mash version found is v2.3
# 2025-07-25 15:53:49.437 | INFO     | input_commands:check_dependencies:566 - mash version is ok.
# 2025-07-25 15:53:49.774 | INFO     | input_commands:check_dependencies:585 - Dnaapler version found is v1.2.0
# 2025-07-25 15:53:49.774 | INFO     | input_commands:check_dependencies:592 - Dnaapler version is ok.
# 2025-07-25 15:53:49.774 | INFO     | input_commands:check_dependencies:604 - Pyrodigal version is v3.6.3
# 2025-07-25 15:53:49.774 | INFO     | input_commands:check_dependencies:605 - Pyrodigal version is ok.
# 2025-07-25 15:53:49.775 | INFO     | input_commands:check_dependencies:617 - Pyrodigal_gv version is v0.3.2
# 2025-07-25 15:53:49.775 | INFO     | input_commands:check_dependencies:618 - Pyrodigal_gv version is ok.
# 2025-07-25 15:53:49.779 | INFO     | input_commands:validate_fasta:237 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta.
# 2025-07-25 15:53:49.779 | INFO     | input_commands:validate_fasta:239 - Input /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta is in FASTA format.
# 2025-07-25 15:53:49.780 | INFO     | input_commands:validate_fasta:244 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta for duplicate FASTA headers.
# 2025-07-25 15:53:49.780 | INFO     | input_commands:validate_fasta:246 - All headers in /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta are unique.
# 2025-07-25 15:53:49.780 | INFO     | input_commands:validate_gene_predictor:275 - Phanotate will be used for gene prediction.
# 2025-07-25 15:53:49.780 | INFO     | __main__:main:280 - Running Phanotate.
# 2025-07-25 15:53:49.782 | INFO     | external_tools:run:50 - Started running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta ...
# 2025-07-25 15:53:55.301 | INFO     | external_tools:run:52 - Done running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta
# 2025-07-25 15:53:55.302 | INFO     | external_tools:run:50 - Started running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta ...
# 2025-07-25 15:54:00.576 | INFO     | external_tools:run:52 - Done running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta
# 2025-07-25 15:54:00.586 | INFO     | __main__:main:309 - Starting tRNA-scanSE.
# 2025-07-25 15:54:00.587 | INFO     | external_tools:run:50 - Started running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta ...
# 2025-07-25 15:54:00.747 | INFO     | external_tools:run:52 - Done running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta
# 2025-07-25 15:54:00.747 | INFO     | processes:run_minced:827 - Running MinCED.
# 2025-07-25 15:54:00.748 | INFO     | external_tools:run:50 - Started running minced /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_minced.gff ...
# 2025-07-25 15:54:00.823 | INFO     | external_tools:run:52 - Done running minced /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_minced.gff
# 2025-07-25 15:54:00.823 | INFO     | processes:run_aragorn:859 - Running Aragorn.
# 2025-07-25 15:54:00.824 | INFO     | external_tools:run:50 - Started running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta ...
# 2025-07-25 15:54:00.831 | INFO     | external_tools:run:52 - Done running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta
# 2025-07-25 15:54:00.831 | INFO     | __main__:main:317 - Starting MMseqs2.
# 2025-07-25 15:54:00.831 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on PHROG Database.
# 2025-07-25 15:54:00.833 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs ...
# 2025-07-25 15:54:00.842 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs
# 2025-07-25 15:54:00.843 | INFO     | external_tools:run:50 - Started running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/tmp_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:55:32.265 | INFO     | external_tools:run:52 - Done running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/tmp_dir/ -s 8.5 --threads 16
# 2025-07-25 15:55:32.266 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:55:32.303 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/mmseqs_results.tsv --full-header --threads 16
# 2025-07-25 15:55:32.304 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on CARD Database.
# 2025-07-25 15:55:32.305 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs ...
# 2025-07-25 15:55:32.315 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs
# 2025-07-25 15:55:32.316 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:55:47.825 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_dir/ -s 8.5 --threads 16
# 2025-07-25 15:55:47.826 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:55:47.846 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/CARD_results.tsv --full-header --threads 16
# 2025-07-25 15:55:47.847 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on VFDB Database.
# 2025-07-25 15:55:47.855 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs ...
# 2025-07-25 15:55:47.867 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs
# 2025-07-25 15:55:47.869 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 15:56:15.372 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_dir/ -s 8.5 --threads 16
# 2025-07-25 15:56:15.374 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/vfdb_results.tsv --full-header --threads 16 ...
# 2025-07-25 15:56:15.390 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/vfdb_results.tsv --full-header --threads 16
# 2025-07-25 15:56:15.391 | INFO     | __main__:main:348 - Running PyHMMER on PHROGs.
# 2025-07-25 15:56:23.350 | INFO     | __main__:main:364 - Post Processing Output.
# 2025-07-25 15:56:23.357 | INFO     | post_processing:create_mmseqs_tophits:2146 - Processing MMseqs2 outputs.
# 2025-07-25 15:56:23.357 | INFO     | post_processing:create_mmseqs_tophits:2147 - Processing PHROGs output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2169: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "mmseqs_eVal"))
# 2025-07-25 15:56:23.465 | INFO     | post_processing:process_vfdb_results:2351 - Processing VFDB output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2375: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "vfdb_eVal"))
# 2025-07-25 15:56:23.471 | INFO     | post_processing:process_vfdb_results:2437 - 0 VFDB virulence factors identified.
# 2025-07-25 15:56:23.471 | INFO     | post_processing:process_card_results:2455 - Processing CARD output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2475: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "CARD_eVal"))
# 2025-07-25 15:56:23.478 | INFO     | post_processing:process_card_results:2578 - 0 CARD AMR genes identified.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:1110: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   total_gff = total_gff.groupby(
# 2025-07-25 15:56:23.513 | INFO     | __main__:main:435 - Converting gff to genbank.
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/Bio/SeqIO/InsdcIO.py:773: BiopythonWarning: Increasing length of locus line to allow long name. This will result in fields that are not in usual positions.
#   warnings.warn(
# 2025-07-25 15:56:23.531 | INFO     | post_processing:extract_terl:1982 - Terminase large subunit found.
# 2025-07-25 15:56:23.535 | INFO     | __main__:main:453 - Finding the closest match for each contig in INPHARED using mash.
# 2025-07-25 15:56:23.535 | INFO     | external_tools:run:50 - Started running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/input_mash_sketch.msh -i ...
# 2025-07-25 15:56:23.539 | INFO     | external_tools:run:52 - Done running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631.fasta -o /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/input_mash_sketch.msh -i
# 2025-07-25 15:56:23.540 | INFO     | external_tools:run_to_stdout:59 - Started running mash dist /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i ...
# 2025-07-25 15:56:24.218 | INFO     | external_tools:run_to_stdout:61 - Done running mash dist /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:473 - Pharokka has finished.
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:474 - Elapsed time: 155.07 seconds
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:476 - If you use Pharokka in your research, please cite:
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:477 - George Bouras, Roshan Nepal, Ghais Houtak, Alkis James Psaltis, Peter-John Wormald, Sarah Vreugde.
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:480 - Pharokka: a fast scalable bacteriophage annotation tool.
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:481 - Bioinformatics, Volume 39, Issue 1, January 2023, btac776.
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:482 - https://doi.org/10.1093/bioinformatics/btac776.
# 2025-07-25 15:56:24.318 | INFO     | __main__:main:483 - You should also cite the full list of tools Pharokka uses, which can be found at https://github.com/gbouras13/pharokka#citation.
#  40%|████      | 2/5 [05:04<07:38, 152.94s/it]
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:558: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/numpy/_core/getlimits.py:90: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# 2025-07-25 15:56:25.396 | INFO     | input_commands:instantiate_dirs:190 - Removing output directory /home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_640753048_000002_640753048_640753089 as -f or --force was specified.
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:95 - Starting Pharokka v1.7.5
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:96 - Command executed: Namespace(infile='/home/snt/SerraPHIM/data/phage_genomes/sample/IMGVR_UViG_640753048_000002_640753048_640753089.fasta', outdir='/home/snt/SerraPHIM/data/pharokka_results/IMGVR_UViG_640753048_000002_640753048_640753089', database='/home/snt/PhageHostLearn-main/pharokka/databases', threads='16', force=True, prefix='Default', locustag='Default', gene_predictor='default', meta=False, split=False, coding_table='11', evalue='1E-05', fast=False, mmseqs2_only=False, meta_hmm=False, dnaapler=False, custom_hmm='', genbank=False, terminase=False, terminase_strand='nothing', terminase_start='nothing', skip_extra_annotations=False, skip_mash=False, minced_args='', mash_distance=0.2, trna_scan_model='general', citation=False)
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:97 - Repository homepage is https://github.com/gbouras13/pharokka
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:98 - Written by George Bouras: george.bouras@adelaide.edu.au
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:100 - Checking database installation in /home/snt/PhageHostLearn-main/pharokka/databases.
# 2025-07-25 15:56:25.407 | INFO     | __main__:main:103 - All databases have been successfully checked.
# 2025-07-25 15:56:25.408 | INFO     | __main__:main:119 - Checking dependencies.
# 2025-07-25 15:56:25.532 | INFO     | input_commands:check_dependencies:390 - Phanotate version found is v1.6.7
# 2025-07-25 15:56:25.532 | INFO     | input_commands:check_dependencies:399 - Phanotate version is ok.
# 2025-07-25 15:56:25.534 | INFO     | input_commands:check_dependencies:420 - MMseqs2 version found is 45111b641859ed0ddd875b94d6fd1aef1a675b7e
# 2025-07-25 15:56:25.534 | INFO     | input_commands:check_dependencies:435 - MMseqs2 version is ok.
# 2025-07-25 15:56:25.579 | INFO     | input_commands:check_dependencies:459 - tRNAscan-SE version found is v2.0.12
# 2025-07-25 15:56:25.579 | INFO     | input_commands:check_dependencies:470 - tRNAscan-SE version is ok.
# 2025-07-25 15:56:25.633 | INFO     | input_commands:check_dependencies:494 - MinCED version found is v0.4.2
# 2025-07-25 15:56:25.633 | INFO     | input_commands:check_dependencies:505 - MinCED version is ok.
# 2025-07-25 15:56:25.635 | INFO     | input_commands:check_dependencies:531 - ARAGORN version found is v1.2.41
# 2025-07-25 15:56:25.635 | INFO     | input_commands:check_dependencies:542 - ARAGORN version is ok.
# 2025-07-25 15:56:25.637 | INFO     | input_commands:check_dependencies:559 - mash version found is v2.3
# 2025-07-25 15:56:25.637 | INFO     | input_commands:check_dependencies:566 - mash version is ok.
# 2025-07-25 15:56:26.096 | INFO     | input_commands:check_dependencies:585 - Dnaapler version found is v1.2.0
# 2025-07-25 15:56:26.096 | INFO     | input_commands:check_dependencies:592 - Dnaapler version is ok.
# 2025-07-25 15:56:26.096 | INFO     | input_commands:check_dependencies:604 - Pyrodigal version is v3.6.3
# 2025-07-25 15:56:26.096 | INFO     | input_commands:check_dependencies:605 - Pyrodigal version is ok.
# ...
# 2025-07-25 16:01:58.104 | INFO     | input_commands:check_dependencies:592 - Dnaapler version is ok.
# 2025-07-25 16:01:58.105 | INFO     | input_commands:check_dependencies:604 - Pyrodigal version is v3.6.3
# 2025-07-25 16:01:58.105 | INFO     | input_commands:check_dependencies:605 - Pyrodigal version is ok.
# 2025-07-25 16:01:58.105 | INFO     | input_commands:check_dependencies:617 - Pyrodigal_gv version is v0.3.2
# 2025-07-25 16:01:58.105 | INFO     | input_commands:check_dependencies:618 - Pyrodigal_gv version is ok.
# 2025-07-25 16:01:58.110 | INFO     | input_commands:validate_fasta:237 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta.
# 2025-07-25 16:01:58.111 | INFO     | input_commands:validate_fasta:239 - Input /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta is in FASTA format.
# 2025-07-25 16:01:58.111 | INFO     | input_commands:validate_fasta:244 - Checking input /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta for duplicate FASTA headers.
# 2025-07-25 16:01:58.111 | INFO     | input_commands:validate_fasta:246 - All headers in /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta are unique.
# 2025-07-25 16:01:58.111 | INFO     | input_commands:validate_gene_predictor:275 - Phanotate will be used for gene prediction.
# 2025-07-25 16:01:58.112 | INFO     | __main__:main:280 - Running Phanotate.
# 2025-07-25 16:01:58.113 | INFO     | external_tools:run:50 - Started running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta ...
# 2025-07-25 16:02:33.277 | INFO     | external_tools:run:52 - Done running phanotate.py -f fasta -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_out_tmp.fasta /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta
# 2025-07-25 16:02:33.278 | INFO     | external_tools:run:50 - Started running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta ...
# 2025-07-25 16:03:09.089 | INFO     | external_tools:run:52 - Done running phanotate.py -f tabular -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_out.txt /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta
# 2025-07-25 16:03:09.117 | INFO     | __main__:main:309 - Starting tRNA-scanSE.
# 2025-07-25 16:03:09.117 | INFO     | external_tools:run:50 - Started running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta ...
# 2025-07-25 16:03:09.797 | INFO     | external_tools:run:52 - Done running tRNAscan-SE --thread 16 -G -Q -j /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/trnascan_out.gff /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta
# 2025-07-25 16:03:09.797 | INFO     | processes:run_minced:827 - Running MinCED.
# 2025-07-25 16:03:09.798 | INFO     | external_tools:run:50 - Started running minced /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_minced.gff ...
# 2025-07-25 16:03:09.899 | INFO     | external_tools:run:52 - Done running minced /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_minced_spacers.txt /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_minced.gff
# 2025-07-25 16:03:09.900 | INFO     | processes:run_aragorn:859 - Running Aragorn.
# 2025-07-25 16:03:09.900 | INFO     | external_tools:run:50 - Started running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta ...
# 2025-07-25 16:03:09.931 | INFO     | external_tools:run:52 - Done running aragorn -l -gcbact -w -m -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/pharokka_aragorn.txt /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta
# 2025-07-25 16:03:09.932 | INFO     | __main__:main:317 - Starting MMseqs2.
# 2025-07-25 16:03:09.932 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on PHROG Database.
# 2025-07-25 16:03:09.933 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs ...
# 2025-07-25 16:03:09.945 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs
# 2025-07-25 16:03:09.946 | INFO     | external_tools:run:50 - Started running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/tmp_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 16:04:49.410 | INFO     | external_tools:run:52 - Done running mmseqs search -e 1E-05 /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/tmp_dir/ -s 8.5 --threads 16
# 2025-07-25 16:04:49.411 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs_results.tsv --full-header --threads 16 ...
# 2025-07-25 16:04:49.448 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/phrogs_profile_db /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/mmseqs_results.tsv --full-header --threads 16
# 2025-07-25 16:04:49.449 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on CARD Database.
# 2025-07-25 16:04:49.452 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs ...
# 2025-07-25 16:04:49.463 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs
# 2025-07-25 16:04:49.464 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 16:05:05.194 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_dir/ -s 8.5 --threads 16
# 2025-07-25 16:05:05.195 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_results.tsv --full-header --threads 16 ...
# 2025-07-25 16:05:05.214 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/CARD /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/CARD_results.tsv --full-header --threads 16
# 2025-07-25 16:05:05.215 | INFO     | processes:run_mmseqs:685 - Running MMseqs2 on VFDB Database.
# 2025-07-25 16:05:05.222 | INFO     | external_tools:run:50 - Started running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs ...
# 2025-07-25 16:05:05.235 | INFO     | external_tools:run:52 - Done running mmseqs createdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/phanotate_aas_tmp.fasta /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs
# 2025-07-25 16:05:05.236 | INFO     | external_tools:run:50 - Started running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_dir/ -s 8.5 --threads 16 ...
# 2025-07-25 16:05:32.254 | INFO     | external_tools:run:52 - Done running mmseqs search --min-seq-id 0.8 -c 0.4 /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_dir/ -s 8.5 --threads 16
# 2025-07-25 16:05:32.255 | INFO     | external_tools:run:50 - Started running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/vfdb_results.tsv --full-header --threads 16 ...
# 2025-07-25 16:05:32.269 | INFO     | external_tools:run:52 - Done running mmseqs createtsv /home/snt/PhageHostLearn-main/pharokka/databases/vfdb /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB_target_dir/target_seqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/VFDB/results_mmseqs /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/vfdb_results.tsv --full-header --threads 16
# 2025-07-25 16:05:32.270 | INFO     | __main__:main:348 - Running PyHMMER on PHROGs.
# 2025-07-25 16:05:42.494 | INFO     | __main__:main:364 - Post Processing Output.
# 2025-07-25 16:05:42.508 | INFO     | post_processing:create_mmseqs_tophits:2146 - Processing MMseqs2 outputs.
# 2025-07-25 16:05:42.508 | INFO     | post_processing:create_mmseqs_tophits:2147 - Processing PHROGs output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2169: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "mmseqs_eVal"))
# 2025-07-25 16:05:42.710 | INFO     | post_processing:process_vfdb_results:2351 - Processing VFDB output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2375: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "vfdb_eVal"))
# 2025-07-25 16:05:42.715 | INFO     | post_processing:process_vfdb_results:2437 - 0 VFDB virulence factors identified.
# 2025-07-25 16:05:42.716 | INFO     | post_processing:process_card_results:2455 - Processing CARD output.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:2475: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nsmallest(1, "CARD_eVal"))
# 2025-07-25 16:05:42.721 | INFO     | post_processing:process_card_results:2578 - 0 CARD AMR genes identified.
# /home/snt/PhageHostLearn-main/pharokka/bin/post_processing.py:1110: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   total_gff = total_gff.groupby(
# 2025-07-25 16:05:42.785 | INFO     | __main__:main:435 - Converting gff to genbank.
# 2025-07-25 16:05:42.829 | INFO     | post_processing:extract_terl:1982 - Terminase large subunit found.
# 2025-07-25 16:05:42.836 | INFO     | __main__:main:453 - Finding the closest match for each contig in INPHARED using mash.
# 2025-07-25 16:05:42.837 | INFO     | external_tools:run:50 - Started running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/input_mash_sketch.msh -i ...
# 2025-07-25 16:05:42.843 | INFO     | external_tools:run:52 - Done running mash sketch /home/snt/SerraPHIM/data/phage_genomes/sample/NC_020083.1.fasta -o /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/input_mash_sketch.msh -i
# 2025-07-25 16:05:42.843 | INFO     | external_tools:run_to_stdout:59 - Started running mash dist /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i ...
# 2025-07-25 16:05:43.499 | INFO     | external_tools:run_to_stdout:61 - Done running mash dist /home/snt/SerraPHIM/data/pharokka_results/NC_020083.1/input_mash_sketch.msh /home/snt/PhageHostLearn-main/pharokka/databases/1Aug2023_genomes.fa.msh -d 0.2 -i
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:473 - Pharokka has finished.
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:474 - Elapsed time: 226.19 seconds
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:476 - If you use Pharokka in your research, please cite:
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:477 - George Bouras, Roshan Nepal, Ghais Houtak, Alkis James Psaltis, Peter-John Wormald, Sarah Vreugde.
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:480 - Pharokka: a fast scalable bacteriophage annotation tool.
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:481 - Bioinformatics, Volume 39, Issue 1, January 2023, btac776.
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:482 - https://doi.org/10.1093/bioinformatics/btac776.
# 2025-07-25 16:05:43.612 | INFO     | __main__:main:483 - You should also cite the full list of tools Pharokka uses, which can be found at https://github.com/gbouras13/pharokka#citation.
# 100%|██████████| 5/5 [14:23<00:00, 172.77s/it]
# Pharokka processing complete.

# %%
# Run RBP detection using PhageRBPdetect_v4
# WARNING: No GPUs in yakuza server!
sp.process_and_detect_rbps_v4(
    data_path, 
    RBP_detect_model_path, 
    data_suffix,
    gpu_index=0,
    threads=16  # 128 cores in yakuza server
)
# Out:
# Using device: cuda
# Processing phages:   0%|          | 0/5 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Inference for uvig_32658: 100%|██████████| 18/18 [00:00<00:00, 26.70it/s]
# Inference for IMGVR_UViG_640753048_000002_640753048_640753089: 100%|██████████| 93/93 [00:01<00:00, 69.34it/s]
# Inference for NC_020083.1: 100%|██████████| 228/228 [00:03<00:00, 63.66it/s]
# Inference for IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631: 100%|██████████| 74/74 [00:01<00:00, 69.43it/s]
# Inference for NC_021563.1: 100%|██████████| 77/77 [00:01<00:00, 68.51it/s]
# Processing phages: 100%|██████████| 5/5 [00:07<00:00,  1.56s/it]
# RBP detection complete. Results saved to 'RBPbase_training.csv'

# %%
# Run Bakta
product_keywords = [
    "capsule", "polysaccharide", "-polysaccharide", "LPS",
    "oligosaccharide polymerase",
    "UDP-", "GDP-",
    "mannose",
    "guanylyltransferase",
    "glycosyltransferase",
    "flippase",
    "-antigen", "O-antigen",
    "outer membrane", "outer core", "omp-",
    "mannosyltransferase",
    "fimbria-",
    "pili-", "pilus",
    "adhesin",
    "cellulose",
    "curli",
    # "receptor", # too generic? any receptors not related to surface receptors? 
    "siderophore receptor", "siderophore",
    "enterobactin receptor",
    "aerobactin receptor",
    "yersiniabactin receptor",
    "salmochelin receptor",
    "phage receptor",
    # "prophage", # how is a possible prophage existence affecting the susceptibility to other phages?
    # "phage", "tail fiber", # + other phage components... (CDS in prophage regions?)
    "porin", "-porin",
    "efflux pump",
    "hemagglutinin", "haemagglutinin",
    "lectin",
    "lipid", "-lipid", 
    # "lipoprotein", # too generic? any lipoproteins not related to cell wall / surface receptors?
    "beta-barrel assembly",
    "autotransporter",
    "pathway protein",
    "flagell-",
    "chemotaxis",
    "transporter membrane", "transmembrane",
    "TonB-dependent receptor", "TonB", "TonB-",
    "chitinase", "lecithinase", "hemolysin", 
    "lipase", "-lipase", 
    "protease", "-protease",
    "exoenzyme-", "virulence", "invasion"
]
gene_keywords = [
    "wza", # (capsule export)
    "wzb", # (tyrosine-protein phosphatase)
    "wzc", # (capsule synthesis tyrosine kinase)
    "galF", # (UDP-glucose pyrophosphorylase)
    "ugd", # (UDP-glucose dehydrogenase)
    "manC", # (GDP-mannose pyrophosphorylase)
    "manB", # (mannose-1-phosphate guanylyltransferase)
    "Wzx", # (O-antigen flippase)
    "Wzy", # (O-antigen polymerase)
    "WaaL", # (O-antigen ligase)
    "Waa-", # (core LPS biosynthesis)
    #"magA", # (K1-specific capsular serotype proteins)
    #"rmpA", # (K2-specific capsular serotype proteins)
    "OmpA", "OmpX", "Omp-", # (outer membrane proteins)
    #"OmpK-", # (Klebsiella-specific outer membrane proteins)
    "TolC", # (outer membrane proteins)
    "OprD", "Opr-", # (outer membrane proteins)
    "HasR", "HasB", # (TonB-dependent outer membrane receptor complex)
    "lpx-", # (lipid A biosynthesis: lpxA, lpxC, lpxD)
    "WbbP", # (mannosyltransferase)
    "fimA", "fimH", # (Type 1 fimbriae)
    "mrkA", "mrkB", "mrkC", # (Type 3 fimbriae)
    "PilQ", "PilX", # (Adhesins)
    "csgA", "csgB", # (Curli fibers)
    "FliD", # (Flagellar hook-associated proteins)
    "CheA", "CheB", "CheR", "CheY", "CheW", "CheZ", "Che-", # (Chemotaxis proteins)
    "FepA", "Fiu", # (Enterobactin receptors)
    "IutA", # (Aerobactin receptors)
    "FyuA", # (Yersiniabactin receptors)
    "IroN" # (Salmochelin receptors)
]
sp.run_bakta_and_extract_receptors(
    bact_genomes_sample_path, # bact_genomes_path, 
    bakta_results_path, 
    bakta_db_path, 
    gene_keywords, product_keywords,
    data_suffix,
    threads=16,  # 128 cores in yakuza server
    training=True
)
# Out:
# Processing genomes:   0%|          | 0/5 [00:00<?, ?it/s]
# Command: bakta --db /home/snt/PhageHostLearn-main/bakta_db/db --output /home/snt/SerraPHIM/data/bakta_results/CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome --force --threads 16 --skip-trna --skip-tmrna --skip-rrna --skip-ncrna --skip-ncrna-region --skip-crispr --skip-pseudo --skip-sorf --skip-gap --skip-plot /home/snt/SerraPHIM/data/bacteria_genomes/sample/CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome.fasta
# Parse genome sequences...
# 	imported: 1
# 	filtered & revised: 1
# 	chromosomes: 1
#
# Start annotation...
# skip tRNA prediction...
# skip tmRNA prediction...
# skip rRNA prediction...
# skip ncRNA prediction...
# skip ncRNA region prediction...
# skip CRISPR array prediction...
# predict & annotate CDSs...
# 	predicted: 5041
# 	discarded spurious: 1
# 	revised translational exceptions: 0
# 	detected IPSs: 4764
# 	found PSCs: 138
# 	found PSCCs: 106
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 7
# 		protein sequences: 50
# 	combine annotations and mark hypotheticals...
# 	analyze hypothetical proteins: 218
# 		detected Pfam hits: 16
# 		calculated proteins statistics
# 	revise special cases...
# skip sORF prediction...
# skip gap annotation...
# detect oriCs/oriVs...
# 	found: 1
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# 	selected: 5041
# improve annotations...
# 	revised gene symbols: 36
#
# Genome statistics:
# 	Genome size: 5,442,880 bp
# 	Contigs/replicons: 1
# 	GC: 56.0 %
# 	N50: 5,442,880
# 	N90: 5,442,880
# 	N ratio: 0.0 %
# 	coding density: 87.0 %
#
# annotation summary:
# 	tRNAs: 0
# 	tmRNAs: 0
# 	rRNAs: 0
# 	ncRNAs: 0
# 	ncRNA regions: 0
# 	CRISPR arrays: 0
# 	CDSs: 5040
# 		hypotheticals: 218
# 		pseudogenes: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 1
# 	oriTs: 0
#
# Export annotation results to: /home/snt/SerraPHIM/data/bakta_results/CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	feature inferences...
# 	skip generation of circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	Genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 3:02 [mm:ss].
# Processing genomes:  20%|██        | 1/5 [03:05<12:22, 185.57s/it]
# Receptor genes:      Sequence Id Type    Start     Stop Strand     Locus Tag  Gene  \
# 21      contig_1  cds    24080    24739      -  EFMCOH_00022  ompA
# 24      contig_1  cds    26068    28056      +  EFMCOH_00025   NaN
# 70      contig_1  cds    77521    78864      +  EFMCOH_00071   NaN
# 89      contig_1  cds    98711   100105      +  EFMCOH_00090   NaN
# 93      contig_1  cds   102091   103785      +  EFMCOH_00094  eptB
# ...          ...  ...      ...      ...    ...           ...   ...
# 4977    contig_1  cds  5369170  5370060      -  EFMCOH_04978  brkB
# 4991    contig_1  cds  5387832  5388425      +  EFMCOH_04992  mobA
# 5019    contig_1  cds  5420906  5422276      +  EFMCOH_05019  glmU
# 5028    contig_1  cds  5430606  5431319      +  EFMCOH_05028  hisM
# 5032    contig_1  cds  5434333  5435382      -  EFMCOH_05032   NaN
#
#                                                 Product  \
# 21                              OmpA family lipoprotein
# 24                                             Lipase 1
# 70    Glycosyltransferase sugar-binding region conta...
# 89                            Outer membrane protein D1
# 93    kdo(2)-lipid A phosphoethanolamine 7''-transfe...
# ...                                                 ...
# 4977               virulence factor BrkB family protein
# 4991       molybdenum cofactor guanylyltransferase MobA
# 5019  bifunctional UDP-N-acetylglucosamine diphospho...
# 5028  Inner membrane amino-acid ABC transporter perm...
# 5032                                      Phospholipase
#
#                                                 DbXrefs
# 21    COG:COG2885, COG:M, GO:0009279, RefSeq:WP_0138...
# 24    KEGG:K12686, RefSeq:WP_254754795.1, SO:0001217...
# 70    RefSeq:WP_013810987.1, SO:0001217, UniParc:UPI...
# 89    RefSeq:WP_254754802.1, SO:0001217, UniParc:UPI...
# 93    COG:COG2194, COG:M, EC:2.7.8.42, GO:0008484, K...
# ...                                                 ...
# 4977  COG:COG1295, COG:S, GO:0005886, RefSeq:WP_0138...
# 4991  EC:2.7.7.77, GO:0003824, GO:0006777, RefSeq:WP...
# 5019  COG:COG1207, COG:M, EC:2.3.1.157, EC:2.7.7.23,...
# 5028  COG:COG0765, COG:E, RefSeq:WP_013815074.1, SO:...
# 5032  RefSeq:WP_013815078.1, SO:0001217, UniParc:UPI...
#
# [394 rows x 9 columns]
# Command: bakta --db /home/snt/PhageHostLearn-main/bakta_db/db --output /home/snt/SerraPHIM/data/bakta_results/OX291654.1_Serratia_marcescens_strain_SJC1039_genome_assembly --force --threads 16 --skip-trna --skip-tmrna --skip-rrna --skip-ncrna --skip-ncrna-region --skip-crispr --skip-pseudo --skip-sorf --skip-gap --skip-plot /home/snt/SerraPHIM/data/bacteria_genomes/sample/OX291654.1_Serratia_marcescens_strain_SJC1039_genome_assembly.fasta
# Parse genome sequences...
# 	imported: 1
# 	filtered & revised: 1
# 	chromosomes: 1
#
# Start annotation...
# skip tRNA prediction...
# skip tmRNA prediction...
# skip rRNA prediction...
# skip ncRNA prediction...
# skip ncRNA region prediction...
# skip CRISPR array prediction...
# predict & annotate CDSs...
# 	predicted: 4566
# 	discarded spurious: 2
# 	revised translational exceptions: 0
# 	detected IPSs: 4332
# 	found PSCs: 199
# 	found PSCCs: 16
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 12
# 		protein sequences: 65
# 	combine annotations and mark hypotheticals...
# 	analyze hypothetical proteins: 103
# 		detected Pfam hits: 3
# 		calculated proteins statistics
# 	revise special cases...
# skip sORF prediction...
# skip gap annotation...
# detect oriCs/oriVs...
# 	found: 2
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# 	selected: 4566
# improve annotations...
# 	revised gene symbols: 66
#
# Genome statistics:
# 	Genome size: 5,048,080 bp
# 	Contigs/replicons: 1
# 	GC: 60.1 %
# 	N50: 5,048,080
# 	N90: 5,048,080
# 	N ratio: 0.0 %
# 	coding density: 87.6 %
#
# annotation summary:
# 	tRNAs: 0
# 	tmRNAs: 0
# 	rRNAs: 0
# 	ncRNAs: 0
# 	ncRNA regions: 0
# 	CRISPR arrays: 0
# 	CDSs: 4564
# 		hypotheticals: 103
# 		pseudogenes: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 2
# 	oriTs: 0
#
# Export annotation results to: /home/snt/SerraPHIM/data/bakta_results/OX291654.1_Serratia_marcescens_strain_SJC1039_genome_assembly
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	feature inferences...
# 	skip generation of circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	Genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 3:01 [mm:ss].
# Processing genomes:  40%|████      | 2/5 [06:09<09:13, 184.50s/it]
# Receptor genes:      Sequence Id Type    Start     Stop Strand     Locus Tag  Gene  \
# 8       contig_1  cds     6425     6943      +  BLNDHM_00009  ompX
# 23      contig_1  cds    18633    19304      +  BLNDHM_00024  ompR
# 27      contig_1  cds    23306    23893      +  BLNDHM_00028  ecpA
# 29      contig_1  cds    24690    27209      +  BLNDHM_00030  ecpC
# 33      contig_1  cds    30978    31691      -  BLNDHM_00034  ompR
# ...          ...  ...      ...      ...    ...           ...   ...
# 4465    contig_1  cds  4948289  4949188      +  BLNDHM_04464  rhaT
# 4473    contig_1  cds  4954569  4955246      -  BLNDHM_04472  csgG
# 4536    contig_1  cds  5015468  5016565      -  BLNDHM_04535  ompC
# 4550    contig_1  cds  5030601  5031230      +  BLNDHM_04549  paiB
# 4561    contig_1  cds  5041899  5043203      +  BLNDHM_04560  bdlA
#
#                                                 Product  \
# 8                           outer membrane protein OmpX
# 23           DNA-binding heavy metal response regulator
# 27           Common pilus major fimbrillin subunit EcpA
# 29                    Outer membrane usher protein EcpC
# 33      DNA-binding dual transcriptional regulator OmpR
# ...                                                 ...
# 4465         putative amino-acid metabolite efflux pump
# 4473  Curli production assembly/transport component ...
# 4536                                              Porin
# 4550    Protease synthase and sporulation protein PAI 2
# 4561                          Chemotaxis regulator BdlA
#
#                                                 DbXrefs
# 8     KEGG:K11934, RefSeq:WP_033637662.1, SO:0001217...
# 23    COG:COG0745, COG:TK, KEGG:K07665, RefSeq:WP_03...
# 27    KEGG:K21964, RefSeq:WP_033646847.1, SO:0001217...
# 29    KEGG:K21966, RefSeq:WP_033646843.1, SO:0001217...
# 33    COG:COG0745, COG:TK, RefSeq:WP_041034140.1, SO...
# ...                                                 ...
# 4465  COG:COG0697, COG:GER, KEGG:K15268, SO:0001217,...
# 4473  COG:COG1462, COG:W, SO:0001217, UniParc:UPI000...
# 4536  COG:COG3203, COG:M, KEGG:K11929, RefSeq:WP_033...
# 4550  COG:COG2808, COG:T, KEGG:K07734, RefSeq:WP_033...
# 4561  COG:COG0840, COG:T, RefSeq:WP_060426525.1, SO:...
#
# [406 rows x 9 columns]
# Command: bakta --db /home/snt/PhageHostLearn-main/bakta_db/db --output /home/snt/SerraPHIM/data/bakta_results/AP013063.1_Serratia_marcescens_SM39_DNA_+_plasmids --force --threads 16 --skip-trna --skip-tmrna --skip-rrna --skip-ncrna --skip-ncrna-region --skip-crispr --skip-pseudo --skip-sorf --skip-gap --skip-plot /home/snt/SerraPHIM/data/bacteria_genomes/sample/AP013063.1_Serratia_marcescens_SM39_DNA_+_plasmids.fasta
# Parse genome sequences...
# 	imported: 3
# 	filtered & revised: 3
# 	chromosomes: 1
# 	plasmids: 2
#
# Start annotation...
# skip tRNA prediction...
# skip tmRNA prediction...
# skip rRNA prediction...
# skip ncRNA prediction...
# skip ncRNA region prediction...
# skip CRISPR array prediction...
# predict & annotate CDSs...
# 	predicted: 4889
# 	discarded spurious: 1
# 	revised translational exceptions: 0
# 	detected IPSs: 4691
# 	found PSCs: 161
# 	found PSCCs: 20
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 23
# 		protein sequences: 67
# 	combine annotations and mark hypotheticals...
# 	analyze hypothetical proteins: 147
# 		detected Pfam hits: 5
# 		calculated proteins statistics
# 	revise special cases...
# skip sORF prediction...
# skip gap annotation...
# detect oriCs/oriVs...
# 	found: 2
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# 	selected: 4890
# improve annotations...
# 	revised gene symbols: 64
#
# Genome statistics:
# 	Genome size: 5,326,023 bp
# 	Contigs/replicons: 3
# 	GC: 59.7 %
# 	N50: 5,225,577
# 	N90: 5,225,577
# 	N ratio: 0.0 %
# 	coding density: 87.4 %
#
# annotation summary:
# 	tRNAs: 0
# 	tmRNAs: 0
# 	rRNAs: 0
# 	ncRNAs: 0
# 	ncRNA regions: 0
# 	CRISPR arrays: 0
# 	CDSs: 4888
# 		hypotheticals: 147
# 		pseudogenes: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 2
# 	oriTs: 0
#
# Export annotation results to: /home/snt/SerraPHIM/data/bakta_results/AP013063.1_Serratia_marcescens_SM39_DNA_+_plasmids
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	feature inferences...
# 	skip generation of circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	Genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 2:57 [mm:ss].
# Processing genomes:  60%|██████    | 3/5 [09:09<06:05, 182.52s/it]
# Receptor genes:      Sequence Id Type  Start   Stop Strand     Locus Tag  Gene  \
# 39      contig_1  cds  46272  48626      -  LCBGCM_00040  lptD
# 68      contig_1  cds  85151  86638      +  LCBGCM_00069  murE
# 69      contig_1  cds  86635  87996      +  LCBGCM_00070  murF
# 71      contig_1  cds  89075  90394      +  LCBGCM_00072  murD
# 74      contig_1  cds  92746  94221      +  LCBGCM_00075  murC
# ...          ...  ...    ...    ...    ...           ...   ...
# 4862    contig_3  cds  24527  24880      +  LCBGCM_04861  traA
# 4872    contig_3  cds  33715  34584      +  LCBGCM_04871  traU
# 4873    contig_3  cds  34590  34985      +  LCBGCM_04872  trbC
# 4875    contig_3  cds  36950  37720      +  LCBGCM_04874  traF
# 4885    contig_3  cds  53145  53660      +  LCBGCM_04884   NaN
#
#                                                 Product  \
# 39                            LPS assembly protein LptD
# 68    UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2,6...
# 69    UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-al...
# 71    UDP-N-acetylmuramoyl-L-alanine--D-glutamate li...
# 74               UDP-N-acetylmuramate--L-alanine ligase
# ...                                                 ...
# 4862     type IV conjugative transfer system pilin TraA
# 4872      conjugal transfer pilus assembly protein TraU
# 4873  type-F conjugative transfer system pilin assem...
# 4875  type-F conjugative transfer system pilin assem...
# 4885                     phospholipase D family protein
#
#                                                 DbXrefs
# 39    COG:COG1452, COG:M, GO:0015920, GO:0019867, GO...
# 68    COG:COG0769, COG:M, EC:6.3.2.13, GO:0005524, G...
# 69    COG:COG0770, COG:M, EC:6.3.2.10, GO:0005524, G...
# 71    COG:COG0771, COG:M, EC:6.3.2.9, GO:0005524, GO...
# 74    COG:COG0773, COG:M, EC:6.3.2.8, GO:0005524, GO...
# ...                                                 ...
# 4862  RefSeq:WP_080335488.1, SO:0001217, UniParc:UPI...
# 4872  KEGG:K12060, SO:0001217, UniRef:UniRef50_P1847...
# 4873  SO:0001217, UniRef:UniRef50_A0A6P1Q6I2, UniRef...
# 4875  KEGG:K12057, SO:0001217, UniRef:UniRef50_A0A6P...
# 4885  RefSeq:WP_041038658.1, SO:0001217, UniParc:UPI...
#
# [416 rows x 9 columns]
# Command: bakta --db /home/snt/PhageHostLearn-main/bakta_db/db --output /home/snt/SerraPHIM/data/bakta_results/AP028466.1_Serratia_marcescens_12BL1_DNA --force --threads 16 --skip-trna --skip-tmrna --skip-rrna --skip-ncrna --skip-ncrna-region --skip-crispr --skip-pseudo --skip-sorf --skip-gap --skip-plot /home/snt/SerraPHIM/data/bacteria_genomes/sample/AP028466.1_Serratia_marcescens_12BL1_DNA.fasta
# Parse genome sequences...
# 	imported: 1
# 	filtered & revised: 1
# 	chromosomes: 1
#
# Start annotation...
# skip tRNA prediction...
# skip tmRNA prediction...
# skip rRNA prediction...
# skip ncRNA prediction...
# skip ncRNA region prediction...
# skip CRISPR array prediction...
# predict & annotate CDSs...
# 	predicted: 4999
# 	discarded spurious: 0
# 	revised translational exceptions: 0
# 	detected IPSs: 4717
# 	found PSCs: 228
# 	found PSCCs: 31
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 15
# 		protein sequences: 65
# 	combine annotations and mark hypotheticals...
# 	analyze hypothetical proteins: 164
# 		detected Pfam hits: 4
# 		calculated proteins statistics
# 	revise special cases...
# skip sORF prediction...
# skip gap annotation...
# detect oriCs/oriVs...
# 	found: 2
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# 	selected: 5001
# improve annotations...
# 	revised gene symbols: 65
#
# Genome statistics:
# 	Genome size: 5,437,989 bp
# 	Contigs/replicons: 1
# 	GC: 59.7 %
# 	N50: 5,437,989
# 	N90: 5,437,989
# 	N ratio: 0.0 %
# 	coding density: 87.7 %
#
# annotation summary:
# 	tRNAs: 0
# 	tmRNAs: 0
# 	rRNAs: 0
# 	ncRNAs: 0
# 	ncRNA regions: 0
# 	CRISPR arrays: 0
# 	CDSs: 4999
# 		hypotheticals: 164
# 		pseudogenes: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 2
# 	oriTs: 0
#
# Export annotation results to: /home/snt/SerraPHIM/data/bakta_results/AP028466.1_Serratia_marcescens_12BL1_DNA
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	feature inferences...
# 	skip generation of circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	Genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 3:25 [mm:ss].
# Processing genomes:  80%|████████  | 4/5 [12:37<03:12, 192.56s/it]
# Receptor genes:      Sequence Id Type    Start     Stop Strand     Locus Tag  Gene  \
# 39      contig_1  cds    46257    48617      -  OANAOL_00040  lptD
# 68      contig_1  cds    85142    86629      +  OANAOL_00069  murE
# 69      contig_1  cds    86626    87987      +  OANAOL_00070  murF
# 71      contig_1  cds    89066    90385      +  OANAOL_00072  murD
# 74      contig_1  cds    92737    94212      +  OANAOL_00075  murC
# ...          ...  ...      ...      ...    ...           ...   ...
# 4955    contig_1  cds  5391145  5392347      -  OANAOL_04954  araJ
# 4983    contig_1  cds  5419174  5420607      +  OANAOL_04982   NaN
# 4987    contig_1  cds  5423699  5424667      -  OANAOL_04986   NaN
# 4990    contig_1  cds  5427576  5428073      -  OANAOL_04989  ompA
# 4997    contig_1  cds  5434195  5435064      -  OANAOL_04996  robA
#
#                                                 Product  \
# 39                            LPS assembly protein LptD
# 68    UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--2,6...
# 69    UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-al...
# 71    UDP-N-acetylmuramoyl-L-alanine--D-glutamate li...
# 74               UDP-N-acetylmuramate--L-alanine ligase
# ...                                                 ...
# 4955             Purine ribonucleoside efflux pump nepI
# 4983  Glycosyltransferase RgtA/B/C/D-like domain-con...
# 4987  Rhamnolipids biosynthesis 3-oxoacyl-[acyl-carr...
# 4990                                OmpA family protein
# 4997  MDR efflux pump AcrAB transcriptional activato...
#
#                                                 DbXrefs
# 39    COG:COG1452, COG:M, GO:0015920, GO:0019867, GO...
# 68    COG:COG0769, COG:M, EC:6.3.2.13, GO:0005524, G...
# 69    COG:COG0770, COG:M, EC:6.3.2.10, GO:0005524, G...
# 71    COG:COG0771, COG:M, EC:6.3.2.9, GO:0005524, GO...
# 74    COG:COG0773, COG:M, EC:6.3.2.8, GO:0005524, GO...
# ...                                                 ...
# 4955  COG:COG2814, COG:G, RefSeq:WP_060422552.1, SO:...
# 4983  RefSeq:WP_060422519.1, SO:0001217, UniParc:UPI...
# 4987  RefSeq:WP_060422508.1, SO:0001217, UniParc:UPI...
# 4990  COG:COG2885, COG:M, RefSeq:WP_033649136.1, SO:...
# 4997  COG:COG3708, COG:K, KEGG:K05804, RefSeq:WP_033...
#
# [425 rows x 9 columns]
# Command: bakta --db /home/snt/PhageHostLearn-main/bakta_db/db --output /home/snt/SerraPHIM/data/bakta_results/CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids --force --threads 16 --skip-trna --skip-tmrna --skip-rrna --skip-ncrna --skip-ncrna-region --skip-crispr --skip-pseudo --skip-sorf --skip-gap --skip-plot /home/snt/SerraPHIM/data/bacteria_genomes/sample/CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids.fasta
# Parse genome sequences...
# 	imported: 2
# 	filtered & revised: 2
# 	chromosomes: 1
# 	plasmids: 1
#
# Start annotation...
# skip tRNA prediction...
# skip tmRNA prediction...
# skip rRNA prediction...
# skip ncRNA prediction...
# skip ncRNA region prediction...
# skip CRISPR array prediction...
# predict & annotate CDSs...
# 	predicted: 4918
# 	discarded spurious: 1
# 	revised translational exceptions: 0
# 	detected IPSs: 4554
# 	found PSCs: 242
# 	found PSCCs: 47
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 7
# 		protein sequences: 51
# 	combine annotations and mark hypotheticals...
# 	analyze hypothetical proteins: 206
# 		detected Pfam hits: 11
# 		calculated proteins statistics
# 	revise special cases...
# skip sORF prediction...
# skip gap annotation...
# detect oriCs/oriVs...
# 	found: 1
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# 	selected: 4918
# improve annotations...
# 	revised gene symbols: 35
#
# Genome statistics:
# 	Genome size: 5,403,731 bp
# 	Contigs/replicons: 2
# 	GC: 56.1 %
# 	N50: 5,328,010
# 	N90: 5,328,010
# 	N ratio: 0.0 %
# 	coding density: 87.0 %
#
# annotation summary:
# 	tRNAs: 0
# 	tmRNAs: 0
# 	rRNAs: 0
# 	ncRNAs: 0
# 	ncRNA regions: 0
# 	CRISPR arrays: 0
# 	CDSs: 4917
# 		hypotheticals: 206
# 		pseudogenes: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 1
# 	oriTs: 0
#
# Export annotation results to: /home/snt/SerraPHIM/data/bakta_results/CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	feature inferences...
# 	skip generation of circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	Genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 3:16 [mm:ss].
# Processing genomes: 100%|██████████| 5/5 [15:56<00:00, 191.26s/it]
# Receptor genes:      Sequence Id Type  Start    Stop Strand     Locus Tag  Gene  \
# 21      contig_1  cds  23947   24606      -  EPGMHD_00022  ompA
# 24      contig_1  cds  25935   27923      +  EPGMHD_00025   NaN
# 67      contig_1  cds  76026   76334      +  EPGMHD_00068  rhuM
# 85      contig_1  cds  96510   97904      +  EPGMHD_00086   NaN
# 89      contig_1  cds  99891  101585      +  EPGMHD_00090  eptB
# ...          ...  ...    ...     ...    ...           ...   ...
# 4879    contig_2  cds  31873   32868      +  EPGMHD_04879  traU
# 4880    contig_2  cds  32880   33485      +  EPGMHD_04880  trbC
# 4882    contig_2  cds  35503   36288      +  EPGMHD_04882  traF
# 4887    contig_2  cds  38412   39791      +  EPGMHD_04887  traH
# 4893    contig_2  cds  52066   52605      +  EPGMHD_04893   NaN
#
#                                                 Product  \
# 21                              OmpA family lipoprotein
# 24                                             Lipase 1
# 67                               virulence protein RhuM
# 85                            Outer membrane protein D1
# 89    kdo(2)-lipid A phosphoethanolamine 7''-transfe...
# ...                                                 ...
# 4879      conjugal transfer pilus assembly protein TraU
# 4880  type-F conjugative transfer system pilin assem...
# 4882  type-F conjugative transfer system pilin assem...
# 4887      conjugal transfer pilus assembly protein TraH
# 4893                                    phospholipase D
#
#                                                 DbXrefs
# 21    COG:COG2885, COG:M, GO:0009279, RefSeq:WP_0049...
# 24    KEGG:K12686, RefSeq:WP_004950619.1, SO:0001217...
# 67    SO:0001217, UniRef:UniRef50_A0A1B8YK09, UniRef...
# 85    RefSeq:WP_004950790.1, SO:0001217, UniParc:UPI...
# 89    COG:COG2194, COG:M, EC:2.7.8.42, GO:0008484, K...
# ...                                                 ...
# 4879  KEGG:K12060, RefSeq:WP_004953915.1, SO:0001217...
# 4880  RefSeq:WP_006322777.1, SO:0001217, UniParc:UPI...
# 4882  KEGG:K12057, RefSeq:WP_004953823.1, SO:0001217...
# 4887  KEGG:K12072, RefSeq:WP_020453980.1, SO:0001217...
# 4893  RefSeq:WP_230554984.1, SO:0001217, UniParc:UPI...
#
# [398 rows x 9 columns]
# Receptor extraction complete. Results saved to /home/snt/SerraPHIM/data/bakta_results/Bact_receptors_training.json and /home/snt/SerraPHIM/data/bakta_results/Bact_receptors_verbose_training.json

# %%
# 3 - FEATURE CONSTRUCTION
# --------------------------------------------------

# ESM-2 features for RBPs
sf.compute_esm2_embeddings_rbp_improved(
    data_path, 
    data_suffix, 
    batch_size=16
)
# Out:
# Embedding sequences: 100%|██████████| 14/14 [01:00<00:00,  4.32s/it]
# Saved embeddings to /home/snt/SerraPHIM/data/esm2_embeddings_rbp_training.csv

# %%
# ESM-2 features for bacterial receptors 
sf.compute_esm2_embeddings_receptors(
    data_path, 
    bakta_results_path, 
    data_suffix,
    aggregate_by_accession=True,  # Set to true during internship
    batch_size=16,
    skip_long_seq=False
)
# Out:
# Will process CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome_288 solo (length=1880 AA)
# Will process CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome_320 solo (length=2154 AA)
# Will process CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome_342 solo (length=3314 AA)
# Will process CP100764.1_Serratia_plymuthica_strain_SASK2000_chromosome_349 solo (length=1607 AA)
# Will process OX291654.1_Serratia_marcescens_strain_SJC1039_genome_assembly_92 solo (length=3548 AA)
# Will process OX291654.1_Serratia_marcescens_strain_SJC1039_genome_assembly_275 solo (length=1608 AA)
# Will process AP013063.1_Serratia_marcescens_SM39_DNA_+_plasmids_141 solo (length=3642 AA)
# Will process AP013063.1_Serratia_marcescens_SM39_DNA_+_plasmids_324 solo (length=1608 AA)
# Will process AP028466.1_Serratia_marcescens_12BL1_DNA_147 solo (length=2722 AA)
# Will process AP028466.1_Serratia_marcescens_12BL1_DNA_271 solo (length=2023 AA)
# Will process AP028466.1_Serratia_marcescens_12BL1_DNA_338 solo (length=1608 AA)
# Will process CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids_285 solo (length=1959 AA)
# Will process CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids_321 solo (length=2680 AA)
# Will process CP006250.1_Serratia_plymuthica_4Rx13_+_plasmids_351 solo (length=1608 AA)
# Embedding batches: 100%|██████████| 127/127 [1:46:50<00:00, 50.48s/it]
# Embedding batches: 100%|██████████| 14/14 [03:05<00:00, 13.27s/it]
# Saved embeddings to: /home/snt/SerraPHIM/data/esm2_embeddings_receptors_training.csv

# %%
# Construct feature matrices
rbp_embeddings_path = data_path + '/esm2_embeddings_rbp' + data_suffix + '.csv'
receptors_embeddings_path = data_path + '/esm2_embeddings_receptors' + data_suffix + '.csv'
interaction_path = data_path + '/interactions'

features_esm2, labels, groups_receptors, groups_phage = sf.construct_feature_matrices_receptors(
    interaction_path, 
    data_suffix, 
    receptors_embeddings_path, 
    rbp_embeddings_path
)
# Out:
# Building feature matrix: 100%|██████████| 20/20 [00:00<00:00, 1008.08it/s]

# %%
features_esm2, labels, groups_receptors, groups_phage
# Out:
# (array([[np.float64(-0.014332249), np.float64(-0.06588216),
#          np.float64(-0.0023698194), ..., np.float64(-0.071024075),
#          np.float64(-0.013574367666666665),
#          np.float64(0.10997433999999999)],
#         [np.float64(-0.014332249), np.float64(-0.06588216),
#          np.float64(-0.0023698194), ..., np.float64(-0.12421417),
#          np.float64(-0.0037242933), np.float64(0.1801741)],
#         [np.float64(-0.014332249), np.float64(-0.06588216),
#          np.float64(-0.0023698194), ..., np.float64(-0.07182163700000001),
#          np.float64(0.0048919260000000004), np.float64(0.0896083225)],
#         ...,
#         [np.float64(-0.015825137), np.float64(-0.06701858),
#          np.float64(-0.001265623), ..., np.float64(-0.12421417),
#          np.float64(-0.0037242933), np.float64(0.1801741)],
#         [np.float64(-0.015825137), np.float64(-0.06701858),
#          np.float64(-0.001265623), ..., np.float64(-0.07182163700000001),
#          np.float64(0.0048919260000000004), np.float64(0.0896083225)],
#         [np.float64(-0.015825137), np.float64(-0.06701858),
#          np.float64(-0.001265623), ..., np.float64(-0.07648365900000001),
#          np.float64(0.025897467374999997),
#          np.float64(0.07415039550000001)]], shape=(20, 2560), dtype=object),
#  array([1, 0, 1, 0, 1, 0, 1, 0, 0, 0, 1, 1, 0, 0, 1, 1, 1, 0, 1, 0]),
#  ['AP013063.1',
#   'AP013063.1',
#   'AP013063.1',
#   'AP013063.1',
#   'AP028466.1',
#   'AP028466.1',
#   'AP028466.1',
#   'AP028466.1',
#   'CP006250.1',
#   'CP006250.1',
#   'CP006250.1',
#   'CP006250.1',
#   'CP100764.1',
#   'CP100764.1',
#   'CP100764.1',
#   'CP100764.1',
#   'OX291654.1',
#   'OX291654.1',
#   'OX291654.1',
#   'OX291654.1'],
#  ['NC_021563.1',
#   'IMGVR_UViG_640753048_000002_640753048_640753089',
#   'IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631',
#   'NC_020083.1',
#   'NC_021563.1',
#   'IMGVR_UViG_640753048_000002_640753048_640753089',
#   'IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631',
#   'NC_020083.1',
#   'NC_021563.1',
#   'IMGVR_UViG_640753048_000002_640753048_640753089',
#   'IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631',
#   'NC_020083.1',
#   'NC_021563.1',
#   'IMGVR_UViG_640753048_000002_640753048_640753089',
#   'IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631',
#   'NC_020083.1',
#   'NC_021563.1',
#   'IMGVR_UViG_640753048_000002_640753048_640753089',
#   'IMGVR_UViG_3300031415_000018_3300031415_Ga0308172_1000631',
#   'NC_020083.1'])

# %%
# 4 - TRAINING & EVALUATING MODELS
# --------------------------------------------------

X_full = features_esm2
y_full = labels
groups_receptors = np.array(groups_receptors)
groups_phage = np.array(groups_phage)

imbalance = np.sum(y_full == 1) / np.sum(y_full == 0)
# Out:
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:13:00] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
search_space = {
    "learning_rate": tune.loguniform(1e-3, 0.3),
    "max_depth": tune.choice([3, 5, 7, 9]),
    "n_estimators": tune.choice([100, 200, 300]),
    "scale_pos_weight": tune.choice(1 / imbalance),
    "subsample": tune.uniform(0.6, 1.0),
    "colsample_bytree": tune.uniform(0.6, 1.0)
}

def train_xgb_tune(config, X, y):
    # Stratified train/test split
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42
    )

    model = XGBClassifier(
        learning_rate=config["learning_rate"],
        max_depth=config["max_depth"],
        n_estimators=config["n_estimators"],
        scale_pos_weight=config["scale_pos_weight"],
        subsample=config["subsample"],
        colsample_bytree=config["colsample_bytree"],
        eval_metric="logloss",
        use_label_encoder=False,
        n_jobs=8
    )
    model.fit(X_train, y_train)
    preds = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, preds)
    
    tune.report({"auc": auc})

# %%
analysis = tune.run(
    partial(train_xgb_tune, X=X_full, y=y_full),
    config=search_space,
    num_samples=30,  # increase for more exhaustive search
    metric="auc",
    mode="max",
    scheduler=ASHAScheduler(max_t=50, grace_period=5),
    resources_per_trial={"cpu": 8},
    storage_path=f"{data_path}/ray_tune_results",
    name="xgb_receptor_tune"
)
# Out:
# 2025-07-25 19:52:21,600	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-07-25 19:53:54</td></tr>
# <tr><td>Running for: </td><td>00:01:32.38        </td></tr>
# <tr><td>Memory:      </td><td>6.4/15.3 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 20.000: None | Iter 5.000: None<br>Logical resource usage: 8.0/16 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc                </th><th style="text-align: right;">  colsample_bytree</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  n_estimators</th><th style="text-align: right;">  scale_pos_weight</th><th style="text-align: right;">  subsample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  auc</th></tr>
# </thead>
# <tbody>
# <tr><td>train_xgb_tune_1d5bc_00000</td><td>TERMINATED</td><td>172.21.5.247:389643</td><td style="text-align: right;">          0.765902</td><td style="text-align: right;">     0.0229313 </td><td style="text-align: right;">          5</td><td style="text-align: right;">           300</td><td style="text-align: right;">          0.778575</td><td style="text-align: right;">   0.602845</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.238736</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00001</td><td>TERMINATED</td><td>172.21.5.247:389644</td><td style="text-align: right;">          0.88709 </td><td style="text-align: right;">     0.0293344 </td><td style="text-align: right;">          7</td><td style="text-align: right;">           100</td><td style="text-align: right;">          0.951049</td><td style="text-align: right;">   0.733634</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.197464</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00002</td><td>TERMINATED</td><td>172.21.5.247:389944</td><td style="text-align: right;">          0.644706</td><td style="text-align: right;">     0.0364152 </td><td style="text-align: right;">          7</td><td style="text-align: right;">           100</td><td style="text-align: right;">          1.72509 </td><td style="text-align: right;">   0.895299</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.122766</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00003</td><td>TERMINATED</td><td>172.21.5.247:389949</td><td style="text-align: right;">          0.716024</td><td style="text-align: right;">     0.0432882 </td><td style="text-align: right;">          5</td><td style="text-align: right;">           200</td><td style="text-align: right;">          0.206944</td><td style="text-align: right;">   0.791245</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.144898</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00004</td><td>TERMINATED</td><td>172.21.5.247:390235</td><td style="text-align: right;">          0.751918</td><td style="text-align: right;">     0.00683854</td><td style="text-align: right;">          5</td><td style="text-align: right;">           100</td><td style="text-align: right;">          6.61129 </td><td style="text-align: right;">   0.910807</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.17205 </td><td style="text-align: right;">1    </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00005</td><td>TERMINATED</td><td>172.21.5.247:390236</td><td style="text-align: right;">          0.760148</td><td style="text-align: right;">     0.00428036</td><td style="text-align: right;">          3</td><td style="text-align: right;">           200</td><td style="text-align: right;">          1.00642 </td><td style="text-align: right;">   0.879841</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.208725</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00006</td><td>TERMINATED</td><td>172.21.5.247:390527</td><td style="text-align: right;">          0.91163 </td><td style="text-align: right;">     0.137713  </td><td style="text-align: right;">          9</td><td style="text-align: right;">           200</td><td style="text-align: right;">          0.976634</td><td style="text-align: right;">   0.746562</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.159523</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00007</td><td>TERMINATED</td><td>172.21.5.247:390528</td><td style="text-align: right;">          0.766385</td><td style="text-align: right;">     0.0244761 </td><td style="text-align: right;">          5</td><td style="text-align: right;">           100</td><td style="text-align: right;">          0.991594</td><td style="text-align: right;">   0.728129</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.131692</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00008</td><td>TERMINATED</td><td>172.21.5.247:390816</td><td style="text-align: right;">          0.644272</td><td style="text-align: right;">     0.0144879 </td><td style="text-align: right;">          7</td><td style="text-align: right;">           300</td><td style="text-align: right;">          3.98733 </td><td style="text-align: right;">   0.985618</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.291236</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00009</td><td>TERMINATED</td><td>172.21.5.247:390821</td><td style="text-align: right;">          0.931815</td><td style="text-align: right;">     0.0541606 </td><td style="text-align: right;">          7</td><td style="text-align: right;">           200</td><td style="text-align: right;">          1.0747  </td><td style="text-align: right;">   0.626137</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.242155</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00010</td><td>TERMINATED</td><td>172.21.5.247:391113</td><td style="text-align: right;">          0.660019</td><td style="text-align: right;">     0.00134288</td><td style="text-align: right;">          9</td><td style="text-align: right;">           300</td><td style="text-align: right;">          0.330794</td><td style="text-align: right;">   0.809899</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.201341</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00011</td><td>TERMINATED</td><td>172.21.5.247:391114</td><td style="text-align: right;">          0.816053</td><td style="text-align: right;">     0.0148243 </td><td style="text-align: right;">          5</td><td style="text-align: right;">           300</td><td style="text-align: right;">          0.158924</td><td style="text-align: right;">   0.869892</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.26443 </td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00012</td><td>TERMINATED</td><td>172.21.5.247:391413</td><td style="text-align: right;">          0.823997</td><td style="text-align: right;">     0.00111556</td><td style="text-align: right;">          7</td><td style="text-align: right;">           200</td><td style="text-align: right
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                </th><th style="text-align: right;">  auc</th></tr>
# </thead>
# <tbody>
# <tr><td>train_xgb_tune_1d5bc_00000</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00001</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00002</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00003</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00004</td><td style="text-align: right;">1    </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00005</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00006</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00007</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00008</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00009</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00010</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00011</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00012</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00013</td><td style="text-align: right;">1    </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00014</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00015</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00016</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00017</td><td style="text-align: right;">1    </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00018</td><td style="text-align: right;">1    </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00019</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00020</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00021</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00022</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00023</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00024</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00025</td><td style="text-align: right;">0.75 </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00026</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00027</td><td style="text-align: right;">0.875</td></tr>
# <tr><td>train_xgb_tune_1d5bc_00028</td><td style="text-align: right;">0.5  </td></tr>
# <tr><td>train_xgb_tune_1d5bc_00029</td><td style="text-align: right;">1    </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2025-07-25 19:53:54,172	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/snt/SerraPHIM/data/ray_tune_results/xgb_receptor_tune' in 0.0095s.
# 2025-07-25 19:53:54,183	INFO tune.py:1041 -- Total run time: 92.58 seconds (92.37 seconds for the tuning loop).

# %%
best_config = analysis.get_best_config(metric="auc", mode="max")
print("Best hyperparameters:", best_config)

# Train final model using best config
best_model = XGBClassifier(
    **best_config,
    eval_metric='logloss',
    use_label_encoder=False,
    n_jobs=8
)
best_model.fit(X_full, y_full)
best_model.save_model(f"{results_path}/xgb_receptor_model_tuned{data_suffix}.json")
# Out:
# Best hyperparameters: {'learning_rate': 0.006838535213235038, 'max_depth': 5, 'n_estimators': 100, 'scale_pos_weight': np.float64(0.7777777777777777), 'subsample': 0.9108073952348492, 'colsample_bytree': 0.751917908204838}
# /home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [20:00:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [raw]
# xgb_final = XGBClassifier(
#     scale_pos_weight=1 / imbalance,
#     learning_rate=0.3,
#     n_estimators=250,
#     max_depth=7,
#     n_jobs=8,
#     eval_metric='logloss',
#     use_label_encoder=False
# )
# xgb_final.fit(X_full, y_full)
# xgb_final.save_model(f"{data_path}/xgb_receptor_model{data_suffix}.json")

# %%
# GROUP STRATEGY — choose one of: 'receptor', 'phage', or 'both'
group_by = 'receptor'

if group_by == 'receptor':
    groups = np.array(groups_receptors)
elif group_by == 'phage':
    groups = np.array(groups_phage)
elif group_by == 'both':
    # Optional: define each group as a (phage, receptor) pair
    groups = np.array([f"{b}_{p}" for b, p in zip(groups_receptors, groups_phage)])
else:
    raise ValueError("Invalid grouping strategy selected.")

print(f"Number of unique groups: {len(set(groups))}")
# Out:
# Number of unique groups: 5

# %%
# Convert group names to numeric codes (required for splitting)
unique_groups = list(set(groups))
group_to_id = {g: i for i, g in enumerate(unique_groups)}
group_ids = np.array([group_to_id[g] for g in groups])

k = 5
gkf = GroupKFold(n_splits=k)
results = []
true_labels = []

for train_idx, test_idx in tqdm(gkf.split(X_full, y_full, groups=group_ids), total=k):
    X_train, X_test = X_full[train_idx], X_full[test_idx]
    y_train, y_test = y_full[train_idx], y_full[test_idx]

    imbalance = np.sum(y_train == 1) / np.sum(y_train == 0)
    best_config["scale_pos_weight"] = 1 / imbalance
    
    xgb = XGBClassifier(
        **best_config,
        n_jobs=8,
        eval_metric='logloss',
        use_label_encoder=False
    )
    xgb.fit(X_train, y_train)
    y_score = xgb.predict_proba(X_test)[:, 1]

    results.append(y_score)
    true_labels.append(y_test)

# Save results
with open(f"{results_path}/serr_receptor_level_kfold_results.pickle", "wb") as f:
    pickle.dump({'scores': results, 'labels': true_labels}, f)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]/home/snt/.pyenv/versions/yakuza_venv/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [20:14:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 100%|██████████| 5/5 [00:00<00:00, 14.63it/s]

# %%
results, true_labels
# Out:
# ([array([0.63587373, 0.36634678, 0.63587373, 0.36634678], dtype=float32),
#   array([0.50473005, 0.39629772, 0.6089619 , 0.49906892], dtype=float32),
#   array([0.50473005, 0.39629772, 0.6089619 , 0.49906892], dtype=float32),
#   array([0.50263625, 0.39459795, 0.60965633, 0.5001147 ], dtype=float32),
#   array([0.63587373, 0.36634678, 0.63587373, 0.36634678], dtype=float32)],
#  [array([0, 0, 1, 1]),
#   array([1, 0, 1, 0]),
#   array([1, 0, 1, 0]),
#   array([1, 0, 1, 0]),
#   array([0, 0, 1, 1])])
